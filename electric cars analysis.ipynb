# %%
#import all libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
ec=pd.read_csv("drive/MyDrive/Colab Notebooks/dataset casestudy/electric car.csv")

# %%
#first five values of a data
ec.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# 3  270 Marvin Miller Dr                                                NaN
# 4     2100 S Waldron Rd                                                NaN
#
#          City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0  Montgomery    AL  36107    NaN           NaN           E  ...
# ...

# %%
ec.shape
# Out:
# (70406, 65)

# %%
ec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70406 entries, 0 to 70405
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    70406 non-null  object
#  1   Station Name                      70406 non-null  object
#  2   Street Address                    70405 non-null  object
#  3   Intersection Directions           4493 non-null   object
#  4   City                              70406 non-null  object
#  5   State                             70406 non-null  object
#  6   ZIP                               70405 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     65204 non-null  object
#  9   Status Code                       70406 non-null  object
#  10  Expected Date                     1218 non-null   object
# ...

# %%
ec.describe()
# Out:
#        Plus4  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count  \
# count    0.0          286.000000        54144.000000       8307.000000
# mean     NaN            3.461538            2.315289          3.576381
# std      NaN            6.548356            3.157387          4.129470
# min      NaN            1.000000            1.000000          1.000000
# 25%      NaN            1.000000            2.000000          1.000000
# 50%      NaN            1.000000            2.000000          2.000000
# 75%      NaN            2.000000            2.000000          4.000000
# max      NaN           51.000000          311.000000         56.000000
#
#            Latitude     Longitude             ID  Federal Agency ID  \
# count  70406.000000  70406.000000   70406.000000         955.000000
# mean      38.929309    -96.061447  148730.326066          13.905759
# std        5.628458     19.545273   54261.672118           6.767439
# ...

# %%
ec.isnull().sum()/len(ec)*100
# Out:
# Fuel Type Code                  0.000000
# Station Name                    0.000000
# Street Address                  0.001420
# Intersection Directions        93.618442
# City                            0.000000
#                                  ...
# CNG PSI                        97.731727
# CNG Vehicle Class              97.696219
# LNG Vehicle Class              99.775587
# EV On-Site Renewable Source    99.474477
# Restricted Access              24.104480
# Length: 65, dtype: float64

# %% [markdown]
# **deleting column which contains more than 50%**

# %%
ec.drop(['Intersection Directions','CNG PSI','CNG Vehicle Class','LNG Vehicle Class','EV On-Site Renewable Source'],axis=1,inplace=True)

# %%
ec.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'Street Address', 'City', 'State',
#        'ZIP', 'Plus4', 'Station Phone', 'Status Code', 'Expected Date',
#        'Groups With Access Code', 'Access Days Time', 'Cards Accepted',
#        'BD Blends', 'NG Fill Type Code', 'NG PSI', 'EV Level1 EVSE Num',
#        'EV Level2 EVSE Num', 'EV DC Fast Count', 'EV Other Info', 'EV Network',
#        'EV Network Web', 'Geocode Status', 'Latitude', 'Longitude',
#        'Date Last Confirmed', 'ID', 'Updated At', 'Owner Type Code',
#        'Federal Agency ID', 'Federal Agency Name', 'Open Date',
#        'Hydrogen Status Link', 'NG Vehicle Class', 'LPG Primary',
#        'E85 Blender Pump', 'EV Connector Types', 'Country',
#        'Intersection Directions (French)', 'Access Days Time (French)',
#        'BD Blends (French)', 'Groups With Access Code (French)',
#        'Hydrogen Is Retail', 'Access Code', 'Access Detail Code',
#        'Federal Agency Code', 'Facility Type', 'CNG Dispenser Num',
# ...

# %%
ec.drop(["Plus4","Expected Date","Cards Accepted","BD Blends","NG Fill Type Code","NG PSI","EV Level1 EVSE Num","EV Level2 EVSE Num","EV DC Fast Count","EV Other Info","Owner Type Code","Federal Agency ID","Federal Agency Name","Hydrogen Status Link","NG Vehicle Class","LPG Primary","E85 Blender Pump","Intersection Directions (French)","Access Days Time (French)","BD Blends (French)","Groups With Access Code (French)","Hydrogen Is Retail","Access Detail Code","Federal Agency Code","Facility Type","CNG Dispenser Num","CNG On-Site Renewable Source","CNG Total Compression Capacity","CNG Storage Capacity","LNG On-Site Renewable Source","E85 Other Ethanol Blends","EV Pricing","EV Pricing (French)","LPG Nozzle Types","Hydrogen Pressures","Hydrogen Standards","CNG Fill Type Code"],axis=1,inplace=True)

# %% [markdown]
# **deleting unwanted column**

# %%
ec.drop(["ZIP","Status Code","Updated At","Restricted Access","EV Network","EV Network Web","Latitude","Longitude","Station Phone"],axis=1,inplace=True)

# %%
ec.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address        City State            Groups With Access Code  \
# 0      2951 Chestnut St  Montgomery    AL                            Private
# 1      340 Whitehall St     Atlanta    GA     Public - Card key at all times
# 2   2424 Piedmont Rd NE     Atlanta    GA          Private - Government only
# 3  270 Marvin Miller Dr     Atlanta    GA                            Private
# 4     2100 S Waldron Rd  Fort Smith    AR  Public - Credit card at all times
#
#   Access Days Time Geocode Status Date Last Confirmed  ID   Open Date  \
# ...

# %% [markdown]
# filling null values

# %%
ec["EV Connector Types"].unique()
# Out:
# array([nan, 'CHADEMO J1772 J1772COMBO', 'J1772', 'CHADEMO J1772',
#        'J1772 NEMA520', 'J1772 NEMA515', 'J1772 TESLA',
#        'CHADEMO J1772 NEMA515', 'J1772 J1772COMBO', 'J1772 NEMA1450',
#        'TESLA', 'CHADEMO', 'CHADEMO J1772 NEMA520 TESLA',
#        'CHADEMO J1772COMBO', 'CHADEMO J1772 J1772COMBO TESLA',
#        'J1772COMBO', 'CHADEMO J1772COMBO NEMA520', 'CHADEMO NEMA520',
#        'J1772COMBO NEMA520', 'J1772 NEMA515 NEMA520',
#        'CHADEMO J1772 NEMA520', 'NEMA1450 TESLA',
#        'CHADEMO J1772 J1772COMBO NEMA520', 'CHADEMO J1772COMBO TESLA',
#        'J1772COMBO NEMA515', 'J1772COMBO TESLA', 'NEMA1450'], dtype=object)

# %%
ec['EV Connector Types']=ec['EV Connector Types'].fillna(ec['EV Connector Types'].mode()[0])

# %%
ec["EV Connector Types"].isnull().sum()
# Out:
# 0

# %%
ec["Access Days Time"].unique()
# Out:
# array([nan, '24 hours daily',
#        '24 hours daily; call 866-809-4869 for Clean Energy card', ...,
#        '7:30am-7pm M-F; 8am-6pm Sat; Closed Sunday',
#        '24 hours daily; Phone App',
#        'Mon 7:00am - 6:00pm; Tue 7:00am - 6:00pm; Wed 7:00am - 6:00pm; Thu 7:00am - 6:00pm; Fri 7:00am - 6:00pm'],
#       dtype=object)

# %%
ec['Access Days Time']=ec['Access Days Time'].fillna(ec['Access Days Time'].mode()[0])

# %%
ec["Access Days Time"].isnull().sum()
# Out:
# 0

# %%
ec.isnull().sum()/len(ec)*100
# Out:
# Fuel Type Code             0.000000
# Station Name               0.000000
# Street Address             0.001420
# City                       0.000000
# State                      0.000000
# Groups With Access Code    0.000000
# Access Days Time           0.000000
# Geocode Status             0.021305
# Date Last Confirmed        0.309633
# ID                         0.000000
# Open Date                  1.556686
# EV Connector Types         0.000000
# Country                    0.000000
# Access Code                0.000000
# dtype: float64

# %%
ec.head()
# Out:
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address        City State            Groups With Access Code  \
# 0      2951 Chestnut St  Montgomery    AL                            Private
# 1      340 Whitehall St     Atlanta    GA     Public - Card key at all times
# 2   2424 Piedmont Rd NE     Atlanta    GA          Private - Government only
# 3  270 Marvin Miller Dr     Atlanta    GA                            Private
# 4     2100 S Waldron Rd  Fort Smith    AR  Public - Credit card at all times
#
#   Access Days Time Geocode Status Date Last Confirmed  ID   Open Date  \
# ...

# %%
ec.drop(["Street Address","ID","Date Last Confirmed","Open Date"],axis=1,inplace=True)

# %%
ec.dropna(inplace=True)

# %%
ec.isnull().sum()/len(ec)*100
# Out:
# Fuel Type Code             0.0
# Station Name               0.0
# City                       0.0
# State                      0.0
# Groups With Access Code    0.0
# Access Days Time           0.0
# Geocode Status             0.0
# EV Connector Types         0.0
# Country                    0.0
# Access Code                0.0
# dtype: float64

# %%
ec.columns
# Out:
# Index(['Fuel Type Code', 'Station Name', 'City', 'State',
#        'Groups With Access Code', 'Access Days Time', 'Geocode Status',
#        'EV Connector Types', 'Country', 'Access Code'],
#       dtype='object')

# %%
ec["Fuel Type Code"].unique()
# Out:
# array(['CNG', 'E85', 'ELEC', 'LNG', 'LPG', 'BD', 'HY'], dtype=object)

# %%
ec["State"].unique()
# Out:
# array(['AL', 'GA', 'AR', 'MA', 'NY', 'IN', 'WY', 'CT', 'LA', 'NM', 'KS',
#        'ID', 'MO', 'TX', 'UT', 'MN', 'NE', 'CO', 'OR', 'OK', 'PA', 'CA',
#        'FL', 'SC', 'NC', 'AZ', 'NV', 'VA', 'MD', 'WA', 'TN', 'SD', 'IA',
#        'IL', 'MI', 'ND', 'NJ', 'MS', 'OH', 'MT', 'RI', 'NH', 'WV', 'WI',
#        'HI', 'VT', 'AK', 'ME', 'KY', 'DC', 'DE', 'AB', 'QC', 'MB', 'SK',
#        'ON', 'BC', 'NL', 'PE', 'NB', 'NS', 'NT', 'YT', 'PR', 'MX'],
#       dtype=object)

# %%
ec["City"].unique()
# Out:
# array(['Montgomery', 'Atlanta', 'Fort Smith', ..., 'New Minas',
#        'Herriman', 'Bluffdale'], dtype=object)

# %%
ec["Groups With Access Code"].unique()
# Out:
# array(['Private', 'Public - Card key at all times',
#        'Private - Government only', 'Public - Credit card at all times',
#        'TEMPORARILY UNAVAILABLE (Public)',
#        'TEMPORARILY UNAVAILABLE (Public - Credit card at all times)',
#        'Private - Fleet customers only', 'Public',
#        'Public - Credit card after hours',
#        'TEMPORARILY UNAVAILABLE (Private)',
#        'Private - Card key at all times', 'Public - Call ahead',
#        'Public - Card key after hours',
#        'TEMPORARILY UNAVAILABLE (Public - Credit card after hours)',
#        'TEMPORARILY UNAVAILABLE (Public - Call ahead)',
#        'TEMPORARILY UNAVAILABLE (Private - Government only)',
#        'PLANNED - not yet accessible (Public - Credit card at all times)',
#        'PLANNED - not yet accessible (Private - Government only)',
#        'Public - Limited hours', 'PLANNED - not yet accessible (Public)',
#        'PLANNED - not yet accessible (Public - Call ahead)',
# ...

# %%
ec["Access Days Time"].unique()
# Out:
# array(['24 hours daily',
#        '24 hours daily; call 866-809-4869 for Clean Energy card',
#        '24 hours daily; call 866-809-4869 for Clean Energy card; Also accepts OGS',
#        ..., '7:30am-7pm M-F; 8am-6pm Sat; Closed Sunday',
#        '24 hours daily; Phone App',
#        'Mon 7:00am - 6:00pm; Tue 7:00am - 6:00pm; Wed 7:00am - 6:00pm; Thu 7:00am - 6:00pm; Fri 7:00am - 6:00pm'],
#       dtype=object)

# %%
ec["Geocode Status"].unique()
# Out:
# array(['200-9', '200-8', 'GPS', '200-6', '200-7', '200-5', '200-4'],
#       dtype=object)

# %%
ec["EV Connector Types"].unique()
# Out:
# array(['J1772', 'CHADEMO J1772 J1772COMBO', 'CHADEMO J1772',
#        'J1772 NEMA520', 'J1772 NEMA515', 'J1772 TESLA',
#        'CHADEMO J1772 NEMA515', 'J1772 J1772COMBO', 'J1772 NEMA1450',
#        'TESLA', 'CHADEMO', 'CHADEMO J1772 NEMA520 TESLA',
#        'CHADEMO J1772COMBO', 'CHADEMO J1772 J1772COMBO TESLA',
#        'J1772COMBO', 'CHADEMO J1772COMBO NEMA520', 'CHADEMO NEMA520',
#        'J1772COMBO NEMA520', 'J1772 NEMA515 NEMA520',
#        'CHADEMO J1772 NEMA520', 'NEMA1450 TESLA',
#        'CHADEMO J1772 J1772COMBO NEMA520', 'CHADEMO J1772COMBO TESLA',
#        'J1772COMBO NEMA515', 'J1772COMBO TESLA', 'NEMA1450'], dtype=object)

# %%
ec["Country"].unique()
# Out:
# array(['US', 'CA'], dtype=object)

# %%
ec["Access Code"].unique()
# Out:
# array(['private', 'public'], dtype=object)

# %%
plt.figure(figsize=(6,7))
ec['Fuel Type Code'].value_counts().plot.pie(autopct='%1.2f%%')
plt.show()

# %% [markdown]
# **electric type fuel code is most compare to others**

# %%
plt.figure(figsize=(6,7))
ec['Country'].value_counts().plot.pie(autopct='%1.2f%%')
plt.show()

# %%
plt.figure(figsize=(6,7))
ec['Access Code'].value_counts().plot.pie(autopct='%1.2f%%')
plt.show()

# %%
ec.head()
# Out:
#   Fuel Type Code                                  Station Name        City  \
# 0            CNG          Spire - Montgomery Operations Center  Montgomery
# 1            CNG                           PS Energy - Atlanta     Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority     Atlanta
# 3            CNG                         United Parcel Service     Atlanta
# 4            CNG                    Arkansas Oklahoma Gas Corp  Fort Smith
#
#   State            Groups With Access Code Access Days Time Geocode Status  \
# 0    AL                            Private   24 hours daily          200-9
# 1    GA     Public - Card key at all times   24 hours daily          200-8
# 2    GA          Private - Government only   24 hours daily          200-8
# 3    GA                            Private   24 hours daily          200-9
# 4    AR  Public - Credit card at all times   24 hours daily          200-9
#
#   EV Connector Types Country Access Code
# ...

# %%
ec["Fuel Type Code"].value_counts()/len(ec)*100
# Out:
# ELEC    86.506798
# E85      6.402807
# LPG      2.652328
# CNG      2.317058
# BD       1.730335
# LNG      0.224461
# HY       0.166214
# Name: Fuel Type Code, dtype: float64

# %%
plt.figure(figsize=(8,5))
sns.countplot(ec["Fuel Type Code"])
plt.title('Fuel type count plot as per category')
plt.show()

# %% [markdown]
# **electric fuel type code is most and HY type is almost negligible compare to others**

# %%
plt.figure(figsize=(8,5))
sns.countplot(ec["Fuel Type Code"],hue=ec["Country"])
plt.title('Fuel type count plot as per country')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=ec["Access Code"],hue=ec["Country"])
plt.title('Fuel type count plot as per country')
plt.show()

# %% [markdown]
# **access code comparison as with country**

# %%
plt.figure(figsize=(8,5))
sns.countplot(ec["Geocode Status"])
plt.title('Geocode Status as per category')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x=ec["Geocode Status"],hue=ec["Fuel Type Code"])
plt.title('Geocode Status as per category')
plt.show()

# %% [markdown]
# **ELECTRIC Type fuel code is dominating amongst the all and specially in gps**

# %%
ec["State"].value_counts()
# Out:
# CA    16106
# QC     3502
# NY     3409
# FL     3101
# TX     3002
#       ...
# AK       58
# YT       30
# PR        6
# NT        3
# MX        1
# Name: State, Length: 65, dtype: int64

# %%
ec["City"].value_counts()
# Out:
# Los Angeles    1586
# San Diego       918
# Montréal        635
# Atlanta         608
# San Jose        587
#                ...
# Quinault          1
# Grants            1
# Vidor             1
# Nyack             1
# Firestone         1
# Name: City, Length: 8278, dtype: int64
